# %%
# Clone the GitHub
# !git clone https://github.com/atikul-islam-sajib/FakeImageGenerate.git
# Out:
# Cloning into 'FakeImageGenerate'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 193 (delta 5), reused 35 (delta 4), pack-reused 155
# Receiving objects: 100% (193/193), 110.37 MiB | 20.51 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# Change the directory
# %cd /content/FakeImageGenerate/
# Out:
# /content/FakeImageGenerate

# %%
# Connect the GPU
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"device # {device}")
# Out:
# device # cuda

# %%
# Run the command line --help to understand the commands
# !python /content/FakeImageGenerate/src/cli.py --help
# Out:
# usage: cli.py [-h] [--image_path IMAGE_PATH] [--batch_size BATCH_SIZE] [--image_size IMAGE_SIZE]
#               [--lr LR] [--epochs EPOCHS] [--display DISPLAY] [--device DEVICE]
#               [--num_samples NUM_SAMPLES] [--latent_space LATENT_SPACE] [--test]
#
# Cli For The Gan
#
# options:
#   -h, --help            show this help message and exit
#   --image_path IMAGE_PATH
#                         Define the image path
#   --batch_size BATCH_SIZE
#                         Define the batch size
#   --image_size IMAGE_SIZE
#                         Define the image size
#   --lr LR               Define the learning rate
#   --epochs EPOCHS       Define the number of epochs
#   --display DISPLAY     Display the results
#   --device DEVICE       Choose the device
#   --num_samples NUM_SAMPLES
#                         Defined the num of samples
#   --latent_space LATENT_SPACE
#                         Define the latent space for creating noise samples
# ...

# %%
# Run the command to train the model
# !python /content/FakeImageGenerate/src/cli.py --image_path /content/drive/MyDrive/anime.zip --batch_size 128 \
                                              --image_size 64 --lr 0.0002 --epochs 50 --device cuda --display True
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# [29/50][0/497] Loss_D: 0.0477 Loss_G: 4.4639 D(x): 0.9689 D(G(z)): 0.0149 / 0.0207
# [29/50][1/497] Loss_D: 0.0627 Loss_G: 4.5907 D(x): 0.9785 D(G(z)): 0.0383 / 0.0169
# [29/50][2/497] Loss_D: 0.0497 Loss_G: 5.0426 D(x): 0.9862 D(G(z)): 0.0340 / 0.0111
# [29/50][3/497] Loss_D: 0.0923 Loss_G: 3.7839 D(x): 0.9378 D(G(z)): 0.0244 / 0.0362
# [29/50][4/497] Loss_D: 0.0829 Loss_G: 4.8373 D(x): 0.9841 D(G(z)): 0.0607 / 0.0133
# [29/50][5/497] Loss_D: 0.1344 Loss_G: 3.1779 D(x): 0.9058 D(G(z)): 0.0264 / 0.0708
# [29/50][6/497] Loss_D: 0.0772 Loss_G: 4.7794 D(x): 0.9913 D(G(z)): 0.0634 / 0.0141
# [29/50][7/497] Loss_D: 0.0861 Loss_G: 4.4104 D(x): 0.9504 D(G(z)): 0.0321 / 0.0227
# [29/50][8/497] Loss_D: 0.0702 Loss_G: 4.1817 D(x): 0.9636 D(G(z)): 0.0295 / 0.0264
# [29/50][9/497] Loss_D: 0.0847 Loss_G: 4.6681 D(x): 0.9715 D(G(z)): 0.0512 / 0.0168
# ...

# %%
# Run the command to test
# !python /content/FakeImageGenerate/src/cli.py --num_samples 20 --latent_space 100 --test

# %%
# Display the Generated image
from IPython.display import Image
Image("/content/FakeImageGenerate/outputs/fake_image.png")
